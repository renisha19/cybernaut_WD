# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed"],
    search_term="java developer",
    location="banglore, karnataka",
    results_wanted=50,
    hours_old=72, # (Indeed is hour specific, others round up to days old)
    country_indeed='INDIA',  # only needed for indeed 
    
    # get more info such as full description, direct job url for linkedin (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
    
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2024-10-17 22:42:25,878 - JobSpy - INFO - Indeed search page: 1
# 2024-10-17 22:42:27,175 - JobSpy - INFO - Indeed finished scraping
# Found 50 jobs
#                  id    site  \
# 0  2b716dbcd5e4b8c1  indeed
# 3  4851738a5566e844  indeed
# 5  aaebfebe7ceedb7c  indeed
# 6  0b09d0c6c425f5ca  indeed
# 7  b7a03fcd9655e9b6  indeed
#
#                                              job_url  \
# 0  https://in.indeed.com/viewjob?jk=2b716dbcd5e4b8c1
# 3  https://in.indeed.com/viewjob?jk=4851738a5566e844
# 5  https://in.indeed.com/viewjob?jk=aaebfebe7ceedb7c
# 6  https://in.indeed.com/viewjob?jk=0b09d0c6c425f5ca
# 7  https://in.indeed.com/viewjob?jk=b7a03fcd9655e9b6
#
#                                       job_url_direct  \
# 0  https://accenture.com/in-en/careers/jobdetails...
# 3  https://careers.wipro.com/jobs/3107158/job?utm...
# 5  https://careers.procore.com/jobs/7f7a3671-1225...
# 6  https://careers.procore.com/jobs/senior-softwa...
# ...
